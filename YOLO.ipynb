# %% [markdown]
# <a href="https://colab.research.google.com/github/aipalak/CV-DL/blob/main/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
HOME
# Out:
# '/content'

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="O2XPsHgnfHuz7x9bCo6Z")
project = rf.workspace("aipalak").project("hard-hat-sample-xkgxd")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Hard-Hat-Sample-1 in yolov8:: 100%|██████████| 211/211 [00:00<00:00, 2160.46it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode= train model=yolov8s.pt data=/content/datasets/Hard-Hat-Sample-1/data.yaml epochs=5 imgsz=448 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 293MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train
# Out:
# args.yaml					    results.png
# confusion_matrix.png				    train_batch0.jpg
# events.out.tfevents.1688397345.8b76f492d6dc.1295.0  train_batch1.jpg
# F1_curve.png					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg
# PR_curve.png					    val_batch0_pred.jpg
# R_curve.png					    weights
# results.csv

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=500)
# Out:
# /content

# %%
Image(filename=f'{HOME}/runs/detect/train/results.png', width=500)

# %%
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=500)
